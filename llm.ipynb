# %% [markdown]
# <a href="https://colab.research.google.com/github/taquion009/Calculator/blob/main/llm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Te damos la bienvenida a Colab
